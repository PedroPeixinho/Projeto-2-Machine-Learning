# %% [markdown]
# ## 👔 Relatório 1 - Business Understanding
#
# #### Projeto final da disciplina Aprendizagem de Máquina
#
# Equipe:
#
# - Kailane Felix (kefs@cin.ufpe.br)
# - Sérgio Barreto (slbp@cin.ufpe.br)
# - Pedro Peixinho (phagp@cin.ufpe.br)

# %% [markdown]
# ### 1. Introdução
#
# O entendimento dos dados é uma etapa crucial no processo de Machine Learning, conforme sugere a metodologia CRISP-DM. Durante essa fase, buscaremos obter uma compreensão clara e profunda dos dados disponíveis, incluindo suas características, qualidade e relevância para o problema em questão. Essa etapa é essencial para identificar possíveis falhas, outliers e inconsistências, bem como para determinar as transformações necessárias para a preparação dos dados para modelagem. Uma análise minuciosa e detalhada dos dados permite a construção de modelos mais precisos e robustos, aumentando a eficácia das soluções desenvolvidas.

# %% [markdown]
# #### **1.1 Breve Descrição do Problema de Negócio:**

# %% [markdown]
# A base de dados fornecida está relacionada a um problema de classificação binária na área de telecomunicações. O dataset contém 15.000 instâncias e 49 características, das quais 48 são numéricas e 1 é categórica. O problema originalmente era um problema de regressão, mas na versão disponibilizada a variável alvo foi binarizada, transformando-se em uma característica nominal de duas classes: positivo ('P') e negativo ('N'). O principal desafio é desenvolver um modelo preditivo que consiga classificar corretamente as instâncias do dataset em uma dessas duas categorias.
#
# Infelizmente, não é possível trazer nenhum insight de como esse problema seria abordado a nível de aplicações no mercado, justamente porque não temos mais informações sobre as variáveis preditoras e a variável alvo. O que podemos supor é que estamos tratando de uma condição crítica no setor que pode ser categorizada em duas classes, e, sendo assim, podemos fazer o necessário para constuir um modelo robusto e generalista.

# %% [markdown]
# #### **1.2 Importância do Problema no Contexto do Negócio ou Setor Específico:**

# %% [markdown]
# No contexto empresarial, a capacidade de classificar dados com precisão é vital para a tomada de decisões informadas. Por exemplo, no setor de marketing, a classificação precisa de leads em potenciais clientes e não clientes pode otimizar campanhas e melhorar a taxa de conversão. A importância do problema de classificação abrange diversos setores, onde uma análise precisa pode resultar em significativas melhorias operacionais e estratégicas.
#
# Dentro do setor de telecomunicações, de onde sabemos que os nossos dados são oriundos, podemos listar algumas das principais aplicações e portanto alguns dos possíveis problemas que estamos lidando:
#
# - Detecção de Fraudes:
# Identificação de padrões suspeitos de comportamento de uso que podem indicar fraudes, como clonagem de SIM ou uso não autorizado de contas.
#
# - Churn Prediction (Previsão de Cancelamento de Clientes):
# Classificação de clientes com alta probabilidade de cancelar o serviço, permitindo ações de retenção personalizadas para esses clientes.
#
# - Recomendação de Planos e Serviços:
# Classificação de clientes com base em seus padrões de uso para recomendar planos e serviços que melhor atendam às suas necessidades, melhorando a satisfação do cliente e aumentando a receita.
#
# - Análise de Sentimentos em Atendimento ao Cliente:
# Classificação de interações de atendimento ao cliente (ex: chamadas, chats) para identificar sentimentos negativos e tomar medidas corretivas rápidas.

# %% [markdown]
# ### 2. Objetivos do Projeto

# %% [markdown]
# #### **2.1 Objetivo principal do projeto**

# %% [markdown]
# O objetivo principal deste projeto é desenvolver e avaliar modelos preditivos capazes de classificar corretamente instâncias do dataset fornecido, que consiste em dados da área de telecomunicações. Especificamente, o problema foi transformado em uma tarefa de classificação binária, onde o objetivo é prever se uma condição crítica ocorre (classe 'P') ou não (classe 'N').

# %% [markdown]
# #### **2.2 Objetivos específicos e metas mensuráveis**

# %% [markdown]
# O objetivo central deste projeto é construir um modelo de aprendizado de máquina que generalize bem o problema para ambas as classes, equilibrando precisão, simplicidade e eficiência computacional.
#
# - Objetivos Específicos
#  - Generalização do Modelo:
#
#     Desenvolver um modelo que tenha um bom desempenho em dados não vistos, garantindo que ele generalize bem para ambas as classes do problema.
#
#  - Menor Complexidade:
#
#     Priorizar modelos que apresentem menor complexidade, facilitando sua implementação e manutenção. Isso inclui a preferência por algoritmos que sejam eficientes em termos de tempo e recursos computacionais.
#
#   - Explicabilidade do Modelo:
#
#     Garantir que o modelo final seja explicável, permitindo uma interpretação clara dos resultados e das influências das variáveis. Isso é essencial para a tomada de decisões baseada em dados e para a aceitação do modelo pelos stakeholders.
#
#   - Eficiência de Processamento:
#
#     Otimizar o modelo para que ele seja eficiente em termos de processamento, reduzindo o tempo de treinamento e predição, especialmente considerando as limitações de capacidade computacional da versão gratuita do Google Colab.
#
# Metas mensuráveis acerca do desempenho do Modelo:
#
# 1. Acurácia: Alcançar uma acurácia mínima de 85% no conjunto de teste.
# 2. F1-Score: Obter um F1-Score mínimo de 0.80, garantindo um equilíbrio entre precisão e recall.
# 3. Curva ROC: Atingir uma área sob a curva (AUC) ROC mínima de 0.85, indicando uma boa separação entre as classes.
# 4. Recall: Obter um recall mínimo de 0.80 para garantir a identificação correta dos verdadeiros positivos.

# %% [markdown]
# #### **2.3 Critérios de sucesso**

# %% [markdown]
# Como pontuamos anteriormente, calculamos metas mensuráveis em relação as métricas de classificação propostas, logo, um dos critérios de sucesso será exatamente o alcance de valores iguais ou maiores do que os estabelecidos.
#
# Além disso, acrescentamos o cumprimento das Etapas do CRISP-DM: Todas as fases do CRISP-DM devem ser devidamente executadas e documentadas, assegurando uma abordagem metodológica completa e organizada.

# %% [markdown]
#  ### 3. Contexto do Negócio

# %% [markdown]
# #### **3.1 Descrição da área de negócio ou setor relacionado à base de dados**

# %% [markdown]
# A área de negócio relacionada ao dataset é o setor de telecomunicações, que envolve a transmissão de informações por meio de tecnologias como telefonia fixa, telefonia móvel, internet e transmissão de dados. Este setor é essencial para a conectividade global, permitindo a comunicação entre indivíduos, empresas e governos.

# %% [markdown]
# #### **3.2 Desafios enfrentados atualmente no setor**

# %% [markdown]
# - Fraudes e Segurança: Com o aumento das transações online e a digitalização dos serviços, as fraudes se tornaram um desafio significativo. Detectar e prevenir atividades fraudulentas é crucial para manter a confiança dos clientes.
#
# - Churn de Clientes: A retenção de clientes é um desafio constante. Com a concorrência acirrada, identificar clientes em risco de cancelamento e implementar estratégias de retenção é vital.
#
# - Qualidade do Serviço: Manter altos níveis de qualidade de serviço (QoS) é essencial. Problemas de conectividade, baixa velocidade de internet e quedas de chamadas são pontos críticos que precisam ser monitorados e solucionados rapidamente.
#
# - Personalização de Serviços: Oferecer serviços personalizados com base nas preferências e padrões de uso dos clientes é um diferencial competitivo. Isso requer um entendimento profundo do comportamento dos clientes.
#
# - Gerenciamento de Recursos: Otimizar a infraestrutura e os recursos de rede para atender à crescente demanda por dados é um desafio constante. Isso inclui a gestão eficiente do espectro e a implementação de novas tecnologias como 5G.

# %% [markdown]
# #### **3.3 Principais stakeholders e suas expectativas**

# %% [markdown]
# - Clientes: Esperam serviços de alta qualidade, segurança, e soluções personalizadas que atendam às suas necessidades específicas.
#
# - Provedores de Serviços de Telecomunicações: Buscam maximizar a retenção de clientes, aumentar a receita por usuário, e reduzir custos operacionais através da eficiência e inovação.
#
# - Reguladores Governamentais: Exigem conformidade com regulamentos de segurança, privacidade e qualidade do serviço, além de promover a concorrência justa no mercado.
#
# - Investidores e Acionistas: Esperam retornos financeiros sólidos, crescimento sustentável e mitigação de riscos.
#
# - Funcionários: Buscam ferramentas e processos eficientes para melhorar o atendimento ao cliente e a manutenção da rede.

# %% [markdown]
#  ### 4. Questões de Negócio

# %% [markdown]
# #### **4.1 Lista de questões de negócio específicas que o projeto deve abordar**

# %% [markdown]
# Como lidamos com um dataset onde as variáveis preditoras estão mascaradas, é desafiador definir as questões de negócio específicas diretamente a partir dos dados. No entanto, podemos nos basear nas possíveis questões de negócio, nas características comuns do setor de telecomunicações e nas problemáticas típicas enfrentadas por empresas do setor. Algumas possíveis questões de negócio específicas podem ser:
#
# - Fraude e Segurança
#   - Como podemos identificar padrões anômalos que indicam possíveis fraudes nos
#   serviços de telecomunicações?
#
# - Churn Prediction (Previsão de Cancelamento de Clientes)
#   - Quais são os fatores que mais influenciam a probabilidade de um cliente cancelar o serviço?
#   - Como podemos prever com precisão os clientes que estão em risco de churn?
#
# - Qualidade do Serviço (QoS)
#   - Quais são os principais indicadores de qualidade de serviço que afetam a satisfação do cliente?
#   - Como podemos prever e prevenir problemas de conectividade antes que eles afetem o cliente?
#
# - Personalização de Serviços
#
#   - Como podemos segmentar clientes com base nos seus padrões de uso para oferecer recomendações de planos mais adequados?
# - Gerenciamento de Recursos
#
#   - Quais são os padrões de uso de rede que podem indicar a necessidade de otimização de recursos?
#   - Como podemos prever picos de demanda para alocar recursos de rede de maneira eficiente?

# %% [markdown]
# #### **4.2 Justificativa para a importância de cada questão**

# %% [markdown]
# - **Identificação e Prevenção de Fraudes**: Proteger a empresa e os clientes contra fraudes é crucial para manter a integridade e a confiança no serviço.
#
# - **Retenção de Clientes**: Minimizar o churn é vital para a estabilidade financeira e crescimento da empresa. Entender os motivos do cancelamento permite ações corretivas.
#
# - **Qualidade do Serviço**: A QoS diretamente afeta a satisfação e a lealdade do cliente. Manter altos níveis de QoS é essencial para evitar a perda de clientes.
#
# - **Personalização de Serviços**: A personalização melhora a experiência do cliente e pode aumentar a receita, oferecendo serviços que atendem melhor às necessidades individuais.
#
# - **Otimização de Recursos**: Gerenciar eficientemente os recursos de rede é crucial para suportar a demanda crescente e garantir a qualidade do serviço, especialmente com a adoção de novas tecnologias.

# %% [markdown]
# ###  5. Fontes de Dados

# %% [markdown]
# **5.1 Identificação das fontes de dados fornecidas.**

# %% [markdown]
# Os dados fornecidos provêm do OpenML, uma plataforma colaborativa para compartilhamento e análise de conjuntos de dados de aprendizado de máquina. Especificamente, o conjunto de dados em questão está identificado como o ID 722 na plataforma OpenML. Numa pesquisa mais profunda, encontramos outras versões desta mesma base, que indicam que se trata de um problema de regressão do setor de telecomunicação que foi apresentado em Weiss & Indurkhya (1995).

# %% [markdown]
# **5.2 Descrição dos dados disponíveis (tipo, formato, volume)**

# %% [markdown]
# - Tipo: Possui 49 atributos, dos quais 48 são numéricos e 1 é nominal (a classe alvo).
# - Formato: Foi disponibilizado no formato `.arff`.
# - Volume: Contém 15.000 instâncias.

# %% [markdown]
# **5.3 Qualidade e integridade dos dados**

# %% [markdown]
# - Número de instâncias: 15.000
# - Número de atributos: 49
# - Número de classes: 2 (nominais: 'P' para valores abaixo da média e 'N' para valores acima da média)
# - Valores ausentes: Não há valores ausentes. Todos os atributos têm dados completos.
# - Qualidade dos dados: Os dados foram binarizados a partir de um conjunto de dados original, onde a classe alvo foi transformada em uma variável nominal binária com base na média dos valores. Em um teste de sanidade inicial com a base e ferramentas de AutoML, já conseguimos afirmar que as variáveis são suficientemente preditoras para a classificação do alvo.

# %% [markdown]
# **5.4 Limitações dos dados existentes**

# %% [markdown]
# - Binarização da classe alvo: A transformação da classe alvo para uma variável binária pode simplificar a análise, mas também pode resultar na perda de nuances presentes nos dados originais.
# - Ausência de atributos categóricos: Todos os atributos, exceto a classe alvo, são numéricos, o que pode limitar a diversidade das análises e modelos que podem ser aplicados.
# - Falta de informação contextual: O conjunto de dados não inclui informações contextuais sobre as características ou as instâncias, o que pode ser uma limitação para determinadas análises que requerem entendimento mais aprofundado do contexto dos dados.

# %% [markdown]
#  ### 6. Restrições e Assunções

# %% [markdown]
# #### **6.1 Restrições de tempo, recursos e dados**

# %% [markdown]
# A principal restrição deste projeto é a falta de informação sobre os dados. Não se sabe o que cada coluna do dataset representa, e o contexto exato do problema também não foi fornecido, o que nos leva a fazer suposições. Além disso, o prazo curto limita o tempo disponível para refinamentos, otimizações e testes aprofundados, restringindo a possibilidade de explorar diferentes abordagens, ajustar hiperparâmetros com precisão e realizar testes extensivos. A infraestrutura do Google Colab, embora conveniente e acessível, não possui poder de processamento robusto, limitando a complexidade dos modelos que podem ser treinados e a quantidade de dados que podem ser processados de maneira eficiente.

# %% [markdown]
# #### **6.2 Assunções feitas durante a fase de entendimento do negócio**

# %% [markdown]
# - Representatividade dos dados
#   - Assumimos que os dados disponíveis são representativos do problema de negócio e das condições reais em que o modelo será aplicado. Isso inclui a suposição de que os dados históricos são indicativos de padrões futuros.
#
# - Consistência e integridade dos dados
#   - Supomos que os dados, apesar de mascarados, são consistentes e íntegros, sem grandes problemas de qualidade que possam comprometer a análise e o desenvolvimento do modelo.
#
# - Relevância das variáveis
#   - Assumimos que as variáveis disponíveis, mesmo mascaradas, contêm informações relevantes para a predição do alvo binário (positivo 'P' e negativo 'N'). A suposição é que a transformação da variável alvo de regressão para classificação manteve a relevância dos preditores.
#
# - Constância das condições de negócio
#   - Assumimos que as condições de negócio e os padrões comportamentais dos clientes não mudarão significativamente durante o período em que o modelo será implementado, permitindo que o modelo desenvolvido com dados históricos continue sendo aplicável.
#
# - Independência das variáveis
#   - Inicialmente, pode-se assumir que as variáveis são independentes umas das outras, embora essa suposição seja geralmente testada e ajustada durante a fase de análise exploratória.
#
# - Disponibilidade de recursos para implementação
#   - Supomos que haverá recursos suficientes (tempo, equipe, infraestrutura) para implementar e manter o modelo uma vez que ele esteja desenvolvido e validado.
#
# - Impacto das ações decorrentes do modelo
#   - Assumimos que as ações tomadas com base nas previsões do modelo (ex.: campanhas de retenção, medidas de segurança) terão um impacto positivo nos indicadores de negócio, como redução de churn ou prevenção de fraudes.

# %% [markdown]
# ### 7. Abordagem Proposta

# %% [markdown]
# #### **7.1 Descrição da abordagem/metodologia que será seguida**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para conduzir este projeto, seguiremos a metodologia CRISP-DM (Cross-Industry Standard Process for Data Mining), uma abordagem amplamente adotada e comprovada para projetos de mineração de dados e aprendizado de máquina.
#
# A metodologia CRISP-DM é composta por seis fases distintas, cada uma desempenhando um papel crucial no desenvolvimento e implementação do modelo de aprendizado de máquina. A seguir, detalhamos cada uma dessas fases:
#
# 1. **Entendimento do Negócio**
#
#   Nesta fase inicial, buscamos compreender os objetivos do projeto, os requisitos de negócios e as expectativas dos stakeholders.
#
# 2. **Entendimento dos Dados**
#
#   Após o entendimento do negócio, a próxima fase envolve a coleta inicial de dados e familiarização com eles.
#
# 3. **Preparação dos Dados**
#
#   Esta fase é fundamental para preparar os dados brutos para a modelagem. Inclui atividades como seleção dos dados que serão usados para análise, limpeza e transformação dos dados.
#
# 4. **Modelagem**
#
#   Com os dados preparados, passamos para a fase de modelagem, onde diferentes algoritmos de aprendizado de máquina serão aplicados.
#
# 5. **Avaliação**
#
#   Nesta fase, os modelos treinados são avaliados e comparados de forma mais rigorosa para garantir que atendem aos objetivos do negócio.
#
# 6. **Implementação**
#
#   A fase final envolve o planejamento da implementação do modelo escolhido em um ambiente de produção.

# %% [markdown]
# #### **7.2 Ferramentas e técnicas a serem utilizadas**

# %% [markdown]
# Utilizaremos uma variedade de ferramentas e técnicas que englobam desde a preparação dos dados até a avaliação final dos modelos. A seguir, detalhamos as ferramentas, bibliotecas e o ambiente de desenvolvimento que serão empregados, além das técnicas específicas para pré-processamento e análises pós modelagem.
#
# 1. Ferramentas e Ambiente de Desenvolvimento
# - Google Colab: Utilizaremos o Google Colab como ambiente de desenvolvimento devido à sua facilidade de uso, capacidade de integração com o Google Drive e suporte para GPUs, o que é essencial para o treinamento de modelos mais complexos, como Redes Neurais.
# - Google Drive: Armazenamento e compartilhamento de dados e notebooks para garantir que todos os membros da equipe tenham acesso aos mesmos recursos.
#
# 2. Bibliotecas Utilizadas
#
# - NumPy
# - Pandas
# - SciPy
# - Scikit-learn
# - XGBoost
# - SHAP
# - Optuna
#
# 3. Técnicas de Pré-processamento
#
# - Verificação mais robusta da presença de valores faltantes.
# - Remoção ou correção de outliers.
# - Normalização/Padronização: Transformação dos dados para que todos os atributos tenham a mesma escala, essencial para algoritmos como K-NN e SVM.
# - Codificação: Conversão de variáveis categóricas, se existirem, em variáveis numéricas.
# - Divisão do conjunto de dados em conjuntos de treinamento e teste usando a função train_test_split do Scikit-learn.
# - Uso de validação cruzada (cross-validation) para uma avaliação mais robusta.
#
# 4. Modelos a Serem Utilizados
# - K-NN (K-Nearest Neighbors): Algoritmo baseado em instâncias que classifica os pontos com base nos vizinhos mais próximos.
# - LVQ (Learning Vector Quantization): Técnica baseada em redes neurais para classificação.
# - Árvore de Decisão: Modelo de árvore de decisão para classificação.
# - SVM (Support Vector Machine): Algoritmo de margens máximas para classificação.
# - Random Forest: Conjunto de árvores de decisão para melhorar a precisão e reduzir o overfitting.
# - Rede Neural MLP (Multi-Layer Perceptron): Rede neural de múltiplas camadas para classificação.
# - Comitê de Redes Neurais Artificiais: Combinação de várias redes neurais para melhorar a performance.
# - Comitê Heterogêneo: Combinação de diferentes tipos de modelos (por exemplo, árvores de decisão, SVM, redes neurais) para aumentar a robustez e a precisão.
#
# 5. Técnicas de Avaliação
#
# - Acurácia: Medida da proporção de predições corretas sobre o total de predições. Utilizaremos a função accuracy_score do Scikit-learn.
# - F1-Score: Média harmônica da precisão e do recall, fornecendo uma medida balanceada da performance. Utilizaremos a função f1_score do Scikit-learn.
# - Curva ROC (Receiver Operating Characteristic): Gráfico que ilustra a performance do modelo em termos de taxa de verdadeiros positivos versus taxa de falsos positivos. Utilizaremos a função roc_curve e a métrica roc_auc_score do - Scikit-learn.
# - Recall: Medida da proporção de verdadeiros positivos corretamente identificados pelo modelo. Utilizaremos a função recall_score do Scikit-learn.
# - Precisão: Medida da proporção de verdadeiros positivos entre todas as instâncias classificadas como positivas pelo modelo. Utilizaremos a função precision_score do Scikit-learn.
# - Curva KS (Kolmogorov-Smirnov): Medida da separação entre as distribuições cumulativas de verdadeiros positivos e falsos positivos. Utilizaremos a biblioteca scipy.stats para calcular a estatística KS.
# - Matriz de Confusão: Tabela que resume o desempenho do modelo, mostrando os acertos e erros para cada classe, permitindo uma análise detalhada das predições. Utilizaremos a função confusion_matrix do Scikit-learn.
#
#
# 6. Análise Final de Importância das Features
#
# - SHAP Values: Esta técnica fornece uma interpretação unificada das saídas dos modelos de aprendizado de máquina, atribuindo a importância de cada feature na predição feita pelo modelo.
#
# - Implementação: Utilizaremos a biblioteca SHAP para calcular os valores SHAP das features. Isso nos permitirá identificar quais features têm maior impacto nas predições do modelo, ajudando na compreensão e explicação do comportamento do modelo.
#
# - Visualização: Criaremos gráficos de importância das features e dependência, que serão utilizados para comunicar os resultados de maneira clara e intuitiva.

# %% [markdown]
# #### **7.3 Cronograma preliminar das etapas do projeto**

# %% [markdown]
# O cronograma contendo as etapas do projeto é mostrado logo a seguir na seção 8.1

# %% [markdown]
#  ### 8. Planejamento do Projeto

# %% [markdown]
# #### **8.1 Cronograma com marcos importantes**

# %% [markdown]
# ![Timeline.png](data:image/png;base64,...)

# %% [markdown]
# #### **8.2 Designação de responsabilidades dentro do grupo**

# %% [markdown]
# A divisão das atividades foi baseada nos tópicos presentes em cada relatório:
#
# 1. **Entendimento do Negócio**
#
# Essa etapa foi feita em conjunto pela equipe.
#
# 2. **Entendimento dos Dados**
#
# - Kailane
#  - Descrição dos Dados
# - Pedro e Sérgio
#  - Exploração dos Dados
#
# 3. **Preparação dos Dados**
#
# - Kailane
#  - Conjunto de Treinamento e Validação
# - Pedro
#  - Implementação das Alterações
# - Sérgio
#  - Resultados da Preparação dos Dados
#
#
# 4. **Modelagem**
#
# - Kailane e Pedro
#  - Resultados da Modelagem (Implementação dos modelos)
# - Sérgio
#  - Comparação dos Modelos
#
# 5. **Avaliação e Implementação**
#
# - Kailane e Sérgio
#  - Avaliação dos Modelos (Evaluation)
# - Pedro
#  - Implantação do Modelo (Deployment)
#
# Os tópicos faltantes são teóricos e serão feitos em conjunto pelo grupo, já que serão feitas discussões acerca desses tópicos.

# %% [markdown]
# #### **8.3 Recursos necessários**
#
#
# **Software**
# - Google Colab: Ambiente de desenvolvimento para escrita e execução de notebooks Python, com suporte a bibliotecas populares de aprendizado de máquina.
# - Google Drive: Armazenamento e compartilhamento de dados e notebooks.
#
# **Acesso a Dados**
# - Conjunto de dados do OpenML: Acesso ao dataset identificado como ID 722 na plataforma OpenML.
# - Google Drive: Para armazenamento dos dados de entrada, resultados intermediários e finais, além de documentos e relatórios do projeto.

# %% [markdown]
#  ### 9. Riscos e Mitigações

# %% [markdown]
# **9.1 Lista de riscos potenciais**
#
# Um dos principais riscos que identificamos para este projeto é a falta de capacidade de processamento da versão gratuita do Google Colab. Esta limitação pode afetar especialmente a etapa de fine-tuning de modelos mais complexos, como Redes Neurais MLP, Comitê de Redes Neurais Artificiais e Comitê Heterogêneo. O treinamento e ajuste fino desses modelos exigem recursos computacionais significativos, incluindo tempo de processamento e memória, que podem exceder as capacidades fornecidas pela versão gratuita do Google Colab.

# %% [markdown]
# **9.2 Estratégias de mitigação para cada risco identificado**

# %% [markdown]
# Para mitigar este risco, consideramos as seguintes opções:
#
# - Levar o projeto para execução local no computador mais potente dentro da equipe quando chegarmos as etapas mais exigentes.
# - Alternativas de ambiente de execução: Avaliar a viabilidade de utilizar outras plataformas de computação em nuvem, como o Kaggle.
# - Estratégias de otimização: Implementar técnicas de otimização e redução de dimensionalidade para diminuir a carga computacional.

# %% [markdown]
#  ### 10. Conclusão

# %% [markdown]
# #### **10.1 Resumo dos objetivos e abordagem**

# %% [markdown]
# O objetivo principal deste projeto é desenvolver e avaliar modelos preditivos capazes de classificar corretamente instâncias do dataset fornecido. Utilizaremos a metodologia CRISP-DM para auxiliar no projeto, realizando todas as etapas de Entendimento do Negócio; Entendimento dos Dados; Preparação dos Dados, realizando seleção dos dados que serão usados para análise, limpeza e transformação dos dados; Modelagem, utilizando KNN, LVQ, árvore de decisão, SVM, random forest, MLP, comitê de redes neurais artificiais e comitê heterogêneo; Avaliação, utilizando as métricas de acurácia, F1-Score, curva ROC, recall, precisão, curva KS e matriz de confusão; e Implementação, utilizando da técnica de SHAP Values para entender a importância de cada feature e realizando visualizações dessas importâncias para alcançar uma melhor compreensão dos insights obtidos.

# %% [markdown]
# #### **10.2 Próximos passos imediatos no projeto**

# %% [markdown]
# 1. Iniciar o pré processamento dos dados
# 2. Organizar o ambiente de compartilhamento de arquivos para que as versões do projeto e da base de dados fiquem ao alcance de todos os membros da equipe

# %% [markdown]
# #### **10.3 Reflexão sobre a importância do entendimento do negócio para o sucesso do projeto**

# %% [markdown]
# O entendimento do negócio é um dos pilares fundamentais para o sucesso de qualquer projeto de aprendizado de máquina. Não é apenas uma fase inicial do projeto, mas uma prática contínua que deve ser mantida ao longo de todo o ciclo de vida do projeto. Ele é essencial para garantir que os modelos desenvolvidos não apenas sejam tecnicamente sólidos, mas também proporcionem valor real e tangível para a organização. Ao alinhar os objetivos técnicos com as necessidades de negócios, maximizamos as chances de sucesso do projeto, garantindo que os resultados obtidos sejam relevantes, aplicáveis e impactantes.

# %% [markdown]
# ### 11. Anexos

# %% [markdown]
# [Quais são os benefícios da IA e machine learning no setor de telecomunicações?](https://www.infranewstelecom.com.br/quais-sao-os-beneficios-da-ia-e-machine-learning-no-setor-de-telecomunicacoes/)
#
# [Como as empresas de telecom estão usando Inteligência artificial e Machine Learning?](https://practiaglobal.com.br/como-as-empresas-de-telecom-estao-usando-inteligencia-artificial-e-machine-learning/)
#
# [Link para a base dados fornecida](https://www.openml.org/search?type=data&status=active&id=722&sort=runs)
#
# [Crisp-DM: as 6 etapas da metodologia do futuro](https://blog.mbauspesalq.com/2022/04/12/crisp-dm-as-6-etapas-da-metodologia-do-futuro/)
#
# [Top 10 Data Science Use cases in Telecom](https://medium.com/activewizards-machine-learning-company/top-10-data-science-use-cases-in-telecom-e9c334d42616)
#
# [Churn Prediction para uma Empresa de Telecomunicações](https://medium.com/data-hackers/prever-o-churn-com-python-sim-9fda9c7dda64)
